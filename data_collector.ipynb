# %%
import datetime, time, os, sys, re
import json
import ast
from pprint import pprint
from time import sleep
import urllib
import requests
import pandas as pd

# API wrappers
import facebook

import sqlite3 as lite

import argparse, configparser
Config = configparser.ConfigParser()
Config.read('config.cnf')

# Load config
FACEBOOK_APP_ID = Config.get('facebook', 'app_id')
FACEBOOK_APP_SECRET = Config.get('facebook', 'app_secret')
ALTMETRIC_KEY = Config.get('altmetric', 'key')

# %%
def init_db():
    litecon = lite.connect('data/metrics.db')

    cols = ("doi TEXT, url TEXT, og_id INTEGER, og_obj TEXT, "
            "fb_comments INTEGER, fb_comment_plugins INTEGER, fb_reactions INTEGER, fb_shares INTEGER, "
            "am_posts INTEGER, am_response TEXT, "
            "timestamp TEXT")

    with litecon:
    # set up SQL tables

        litecur = litecon.cursor()
        # the sample, with two columns for either the Tweet itself, or the error in trying to retrieve it
        litecur.execute("CREATE TABLE IF NOT EXISTS wos ({})".format(cols))

        litecur.execute("CREATE UNIQUE INDEX IF NOT EXISTS wos_doi ON wos(doi)")
        
    return litecon

# %%
# Retrieve App Access Token
def init_fb(app_id, app_secret):           
    payload = {'grant_type': 'client_credentials', 'client_id': app_id, 'client_secret': app_secret}
    try:
        r = requests.post('https://graph.facebook.com/oauth/access_token?', params = payload)
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        print(e)
        return False
    
    r = ast.literal_eval(r.text)['access_token']
    print("Generated access token: " + r)
    
    return facebook.GraphAPI(r)

# %%
# Adopted from PyAltmetric (https://github.com/CenterForOpenScience/PyAltmetric)
# and also pyAltmetric (https://github.com/wearp/pyaltmetric)

class AltmetricException(Exception):
    """Base class for any pyaltmetric error."""
    pass

class JSONParseException(AltmetricException):
    """
    Failed to turn HTTP Response into JSON.
    Site is probably in the wrong format.
    """
    pass

class AltmetricHTTPException(AltmetricException):
    """A query argument or setting was formatted incorrectly."""
    def __init__(self, status_code):
        response_codes = {
            403:"You are not authorized for this call.",
            420:"Rate Limit Reached",
            502:"API is down.",
        }
        super(AltmetricHTTPException, self).__init__(
            response_codes.get(status_code, status_code)
        )

class Altmetric(object):
    def __init__(self, api_key = None, api_version = 'v1'):
        """Cache API key and version."""
        self._api_version = api_version
        if self._api_version != 'v1':
            warnings.warn("This wrapper has only been tested with API v1."
                          "If you try another version it will probably break.")

        self._api_url = "http://api.altmetric.com/{}/".format(self._api_version)

        self._api_key = {}
        if api_key:
            self._api_key = {'key': api_key}
            
    def doi(self, doi, fetch = False, **kwargs):
        if fetch:
            return self._get_altmetrics_detailed("doi", doi, **kwargs)
        else:
            return self._get_altmetrics("doi", doi, **kwargs)
        
    def uri(self, uri, fetch = False, **kwargs):
        if fetch:
            return self._get_altmetrics_detailed("uri", uri, **kwargs)
        else:
            return self._get_altmetrics("uri", uri, **kwargs)
        
    def _get_altmetrics(self, method, *args, **kwargs):
        """
        Request information from Altmetric. Return a dictionary.
        """
        request_url = self._api_url + method + "/" + "/".join([a for a in args])
        params = kwargs or {}
        params.update(self._api_key)
        response = requests.get(request_url, params = params)
        if response.status_code == 200:
            try:
                return response.json()
            except ValueError as e:
                raise JSONParseException(e.message)
        elif response.status_code in (404, 400):
            return {}
        else:
            raise AltmetricHTTPException(response.status_code)
            
    def _get_altmetrics_detailed(self, method, *args, **kwargs):
        """
        Request information from Altmetric. Return a dictionary.
        """
        request_url = self._api_url + "fetch/" + method + "/" + "/".join([a for a in args])
        params = kwargs or {}
        params.update(self._api_key)
        response = requests.get(request_url, params = params)
        if response.status_code == 200:
            try:
                return response.json()
            except ValueError as e:
                raise JSONParseException(e.message)
        elif response.status_code in (404, 400):
            return {}
        else:
            raise AltmetricHTTPException(response.status_code)

# %%
def __save_row(doi, url, timestamp, fb_response, altmetric_response, fb_error = None, altmetric_error = None):
    '''
    Do the actual SQLite update with the info collected
    '''    
    if 'og_object' in fb_response:
        og_id = fb_response['og_object']['id']
        og_object = json.dumps(fb_response['og_object'])
        fb_comment_count = fb_response['engagement']['comment_count']
        fb_comment_plugin_count = fb_response['engagement']['comment_plugin_count']
        fb_reaction_count = fb_response['engagement']['reaction_count']
        fb_share_count = fb_response['engagement']['share_count']
    else:
        eng = None
        og_id = None
        og_object = None
        fb_comment_count = None
        fb_comment_plugin_count = None
        fb_reaction_count = None
        fb_share_count = None
    
    try:
        am_posts_count = altmetric_response['counts']['facebook']['posts_count']
    except:
        am_posts_count = None
    
    row = (doi, url, og_id, og_object,
           fb_comment_count,
           fb_comment_plugin_count,
           fb_reaction_count,
           fb_share_count,
           am_posts_count,
           json.dumps(altmetric_response),
           timestamp)
    
    with litecon:
        litecur = litecon.cursor()

        if fb_error: 
            try: 
                m = fb_error.reason
            except:
                m = str(fb_error)
            litecur.execute('UPDATE wos SET error = ?, modified = ? WHERE tweet_id = ?', (m, now, tweet_id))    

        else:
            litecur.execute('''INSERT OR IGNORE INTO wos VALUES (?,?,?,?,?,?,?,?,?,?,?)''', row)

# %%
litecon = init_db()
fb_graph = init_fb(FACEBOOK_APP_ID, FACEBOOK_APP_SECRET)
altmetric = Altmetric(api_key = ALTMETRIC_KEY)

df = pd.read_csv("data/wos_100k.csv", encoding = 'utf8')
dois = df.doi
# Out:
# Generated access token: 287299458433880|6Y_ml710QWnU7HBYLWjaneoWVKU

# %%
for doi in dois.head(300):
    now = datetime.datetime.now()
    try:
        r = requests.head('https://doi.org/{}'.format(doi), allow_redirects=True, timeout=3)
        url = r.url
    except requests.exceptions.Timeout:
        url = "timeout"
    except requests.exceptions.TooManyRedirects:
        url = "too_many_redirects"
    except requests.exceptions.RequestException as e:
        url = str(e)
        
    print(doi, url)
    
    try:
        fb_response = fb_graph.get_object(id=url, fields="engagement, og_object")
    except:
        fb_response = {}
    
    try:
        am_response = altmetric.doi(doi=doi, fetch=True)
    except:
        am_response = None

    __save_row(doi, url, now.strftime("%Y-%m-%d %H:%M:%S"), fb_response, am_response)
    new = datetime.datetime.now()
    delta = new - now
    if delta.seconds < 1:
        time.sleep(1- delta.total_seconds())
# Out:
# 10.1063/1.4898570 http://aip.scitation.org/doi/10.1063/1.4898570
# 10.1103/physrevlett.104.215902 https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.104.215902
# 10.1016/j.chc.2009.03.002 http://linkinghub.elsevier.com/retrieve/pii/S105649930900025X
# 10.1016/j.tele.2013.08.003 http://linkinghub.elsevier.com/retrieve/pii/S0736585313000415
# 10.1371/journal.pone.0007695 http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0007695
# 10.1007/s11442-011-0878-x https://link.springer.com/article/10.1007%2Fs11442-011-0878-x
# 10.1111/j.1365-2486.2011.02512.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1365-2486.2011.02512.x
# 10.1103/physrevlett.112.155702 https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.112.155702
# 10.1103/physrevx.4.011019 https://journals.aps.org/prx/abstract/10.1103/PhysRevX.4.011019
# 10.1128/mcb.01197-14 http://mcb.asm.org/content/35/7/1157
# 10.1016/j.jglr.2009.12.001 http://linkinghub.elsevier.com/retrieve/pii/S0380133009002196
# 10.1016/j.jorganchem.2012.04.002 http://linkinghub.elsevier.com/retrieve/pii/S0022328X12002008
# 10.1016/j.aap.2014.03.017 http://linkinghub.elsevier.com/retrieve/pii/S0001457514001031
# 10.1016/j.amc.2011.12.012 http://linkinghub.elsevier.com/retrieve/pii/S0096300311014706
# 10.3109/10520295.2010.515491 http://www.tandfonline.com/doi/full/10.3109/10520295.2010.515491
# 10.1093/ndt/gfs278 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1186/1472-6920-12-127 https://bmcmededuc.biomedcentral.com/articles/10.1186/1472-6920-12-127
# 10.1007/s00421-010-1368-z https://link.springer.com/article/10.1007%2Fs00421-010-1368-z
# 10.1515/hsz-2012-0246 timeout
# 10.1002/zaac.201400517 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/zaac.201400517
# 10.1111/avj.12103 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/avj.12103
# 10.1145/1467247.1467265 https://dl.acm.org/citation.cfm?doid=1467247.1467265
# 10.1136/bjsm.2008.050989 http://bjsm.bmj.com/cgi/doi/10.1136/bjsm.2008.050989
# 10.1016/j.memsci.2011.09.027 http://linkinghub.elsevier.com/retrieve/pii/S0376738811006983
# 10.1016/j.tetlet.2013.07.122 http://linkinghub.elsevier.com/retrieve/pii/S0040403913012902
# 10.1016/j.anifeedsci.2009.10.007 http://linkinghub.elsevier.com/retrieve/pii/S037784010900340X
# 10.1080/03610926.2011.620212 http://www.tandfonline.com/doi/abs/10.1080/03610926.2011.620212
# 10.1088/0256-307x/28/1/014204 timeout
# 10.1039/b811630j ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s10577-009-9092-4 https://link.springer.com/article/10.1007%2Fs10577-009-9092-4
# 10.1186/1532-429x-16-29 https://jcmr-online.biomedcentral.com/articles/10.1186/1532-429X-16-29
# 10.3138/ptc.2012-01bh timeout
# 10.1111/j.1467-923x.2012.02271.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1467-923X.2012.02271.x
# 10.1016/j.yhbeh.2012.02.023 http://linkinghub.elsevier.com/retrieve/pii/S0018506X12000542
# 10.1016/j.ijrobp.2009.02.026 http://linkinghub.elsevier.com/retrieve/pii/S0360301609002533
# 10.1016/j.nima.2011.11.052 http://linkinghub.elsevier.com/retrieve/pii/S0168900211020948
# 10.1016/j.snb.2011.09.006 http://linkinghub.elsevier.com/retrieve/pii/S0925400511008082
# 10.3832/ifor0496-002 http://www.sisef.it/iforest/contents/?id=ifor0496-002
# 10.1177/1753425910383725 timeout
# 10.1007/s11079-013-9299-z https://link.springer.com/article/10.1007%2Fs11079-013-9299-z
# 10.1186/1741-7007-10-51 https://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51
# 10.1364/oe.22.022308 https://www.osapublishing.org/oe/abstract.cfm?uri=oe-22-19-22308
# 10.1899/10-079.1 http://www.journals.uchicago.edu/doi/10.1899/10-079.1
# 10.1002/adem.201100082 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/adem.201100082
# 10.1002/aic.14493 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/aic.14493
# 10.1016/j.peptides.2012.09.013 http://linkinghub.elsevier.com/retrieve/pii/S0196978112003981
# 10.1016/j.precamres.2013.07.019 http://linkinghub.elsevier.com/retrieve/pii/S0301926813002301
# 10.3354/ab00221 http://www.int-res.com/abstracts/ab/v8/n2/p169-177/
# 10.7150/ijbs.4664 http://www.ijbs.com/v08p1431.htm
# 10.1371/journal.pone.0119813 http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0119813
# 10.1039/c4nr07262f ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s10461-013-0609-7 https://link.springer.com/article/10.1007%2Fs10461-013-0609-7
# 10.1002/app.37983 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/app.37983
# 10.1063/1.4774215 http://aip.scitation.org/doi/10.1063/1.4774215
# 10.1017/s0017089511000334 https://www.cambridge.org/core/journals/glasgow-mathematical-journal/article/on-the-cohomology-of-certain-quotients-of-the-spectrum-bp/37ECBD2EC7CD29B72B175FA1242B7E73
# 10.1016/j.renene.2010.10.032 http://linkinghub.elsevier.com/retrieve/pii/S0960148110005471
# 10.1016/j.jas.2011.11.025 http://linkinghub.elsevier.com/retrieve/pii/S0305440311004468
# 10.1155/2013/480597 https://www.hindawi.com/journals/ecam/2013/480597/
# 10.1080/03056244.2011.603180 http://www.tandfonline.com/doi/abs/10.1080/03056244.2011.603180
# 10.1089/sur.2008.0020 http://online.liebertpub.com/doi/abs/10.1089/sur.2008.0020
# 10.1039/c3cc38783f ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1039/c1jm14459f ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.3923/ijp.2012.30.38 http://www.scialert.net/abstract/?doi=ijp.2012.30.38
# 10.1158/1535-7163.mct-11-0578 http://mct.aacrjournals.org/cgi/doi/10.1158/1535-7163.MCT-11-0578
# 10.1681/asn.2012020127 http://jasn.asnjournals.org/content/24/1/19
# 10.1016/j.foodhyd.2010.02.002 http://linkinghub.elsevier.com/retrieve/pii/S0268005X10000238
# 10.1016/j.arcmed.2013.11.006 http://linkinghub.elsevier.com/retrieve/pii/S0188440913002816
# 10.1016/j.powtec.2010.05.028 http://linkinghub.elsevier.com/retrieve/pii/S0032591010002792
# 10.1016/j.ejphar.2009.08.024 http://linkinghub.elsevier.com/retrieve/pii/S001429990900675X
# 10.1016/j.minpro.2015.03.005 http://linkinghub.elsevier.com/retrieve/pii/S0301751615000460
# 10.1109/tsp.2015.2413384 http://ieeexplore.ieee.org:80/document/7060685/?reload=true
# 10.1227/neu.0b013e3182889e27 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1093/nar/gks243 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1134/s1070428010040287 https://link.springer.com/article/10.1134%2FS1070428010040287
# 10.1134/s0036024412030259 https://link.springer.com/article/10.1134%2FS0036024412030259
# 10.5755/j01.ee.26.2.2818 http://www.inzeko.ktu.lt/index.php/EE/article/view/2818
# 10.1016/j.jbusres.2011.03.016 http://linkinghub.elsevier.com/retrieve/pii/S0148296311001159
# 10.1016/j.bmcl.2013.09.023 http://linkinghub.elsevier.com/retrieve/pii/S0960894X13010974
# 10.1016/j.jlumin.2012.08.029 http://linkinghub.elsevier.com/retrieve/pii/S0022231312005108
# 10.3109/15376516.2010.483070 http://www.tandfonline.com/doi/full/10.3109/15376516.2010.483070
# 10.1080/01488376.2014.987941 http://www.tandfonline.com/doi/full/10.1080/01488376.2014.987941
# 10.1097/dbp.0b013e3182168f95 timeout
# 10.1177/0022034510383691 timeout
# 10.1149/1.3147376 http://jes.ecsdl.org/content/156/8/J215
# 10.1071/ah09546 http://www.publish.csiro.au/AH/AH09546
# 10.1016/j.optcom.2011.03.042 http://linkinghub.elsevier.com/retrieve/pii/S0030401811003130
# 10.1016/j.amjsurg.2010.05.009 http://linkinghub.elsevier.com/retrieve/pii/S0002961010005702
# 10.1016/j.colsurfb.2011.09.010 http://linkinghub.elsevier.com/retrieve/pii/S0927776511005170
# 10.1016/j.surfcoat.2011.01.008 http://linkinghub.elsevier.com/retrieve/pii/S025789721100020X
# 10.1016/j.jcat.2011.06.008 http://linkinghub.elsevier.com/retrieve/pii/S0021951711001941
# 10.1080/10286020.2013.808195 http://www.tandfonline.com/doi/abs/10.1080/10286020.2013.808195
# 10.1080/14685248.2014.957383 http://www.tandfonline.com/doi/abs/10.1080/14685248.2014.957383
# 10.1080/09668130902753325 http://www.tandfonline.com/doi/full/10.1080/09668130902753325
# 10.1371/journal.pone.0118273 http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0118273
# 10.1007/s00105-012-2444-6 https://link.springer.com/article/10.1007%2Fs00105-012-2444-6
# 10.2353/ajpath.2010.100377 http://linkinghub.elsevier.com/retrieve/pii/S0002944010629033
# 10.1016/j.scient.2011.08.008 http://linkinghub.elsevier.com/retrieve/pii/S1026309811001581
# 10.1016/j.technovation.2012.03.003 http://linkinghub.elsevier.com/retrieve/pii/S0166497212000326
# 10.1016/j.jpba.2010.01.012 http://linkinghub.elsevier.com/retrieve/pii/S0731708510000154
# 10.1016/j.poly.2011.10.040 http://linkinghub.elsevier.com/retrieve/pii/S0277538711006814
# 10.1088/0957-0233/25/7/075011 http://iopscience.iop.org/article/10.1088/0957-0233/25/7/075011/meta;jsessionid=999716E87F70A8451491F2E13FDA66DB.ip-10-40-1-105
# 10.1007/s10646-009-0319-0 https://link.springer.com/article/10.1007%2Fs10646-009-0319-0
# 10.1021/jf401837a http://pubs.acs.org/doi/abs/10.1021/jf401837a
# 10.1074/jbc.m113.540088 http://www.jbc.org/content/289/19/13232
# 10.1128/jvi.00728-12 http://jvi.asm.org/content/86/16/8482
# 10.1051/0004-6361/200913937 timeout
# 10.1088/1751-8113/42/5/055303 timeout
# 10.1093/nar/gkp350 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1039/c3dt53594k ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s10209-011-0265-5 https://link.springer.com/article/10.1007%2Fs10209-011-0265-5
# 10.1007/s11051-009-9608-z https://link.springer.com/article/10.1007%2Fs11051-009-9608-z
# 10.1002/anie.201410672 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/anie.201410672
# 10.1002/eat.22102 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/eat.22102
# 10.1021/cg800129u timeout
# 10.1016/j.bios.2009.01.015 http://linkinghub.elsevier.com/retrieve/pii/S0956566309000426
# 10.1016/j.jht.2014.02.004 http://linkinghub.elsevier.com/retrieve/pii/S0894113014000192
# 10.1109/tcad.2013.2284109 http://ieeexplore.ieee.org:80/document/6714475/?reload=true
# 10.1089/ten.tea.2007.0358 http://online.liebertpub.com/doi/abs/10.1089/ten.tea.2007.0358
# 10.1093/bioinformatics/btt439 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1007/s00232-014-9700-x https://link.springer.com/article/10.1007%2Fs00232-014-9700-x
# 10.1007/s10854-015-3177-y https://link.springer.com/article/10.1007%2Fs10854-015-3177-y
# 10.1111/j.1096-3642.2009.00480.x ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1111/j.1095-8312.2009.01201.x ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1002/pi.4477 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/pi.4477
# 10.1016/j.cell.2014.05.039 http://linkinghub.elsevier.com/retrieve/pii/S0092867414007405
# 10.1016/j.chemgeo.2010.10.001 http://linkinghub.elsevier.com/retrieve/pii/S0009254110003529
# 10.1016/j.biopha.2009.06.005 http://linkinghub.elsevier.com/retrieve/pii/S075333220900170X
# 10.1097/pep.0b013e3182691c48 timeout
# 10.1093/jac/dks431 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1007/s00210-013-0950-4 https://link.springer.com/article/10.1007%2Fs00210-013-0950-4
# 10.1111/ijfs.12642 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/ijfs.12642
# 10.1061/(asce)0733-9445(2009)135:2(159) http://ascelibrary.org/doi/10.1061/%28ASCE%290733-9445%282009%29135%3A2%28159%29
# 10.1016/j.exer.2010.05.019 http://linkinghub.elsevier.com/retrieve/pii/S0014483510001685
# 10.1016/j.rbmo.2014.12.011 http://linkinghub.elsevier.com/retrieve/pii/S1472648315000048
# 10.1016/j.jcs.2011.05.001 http://linkinghub.elsevier.com/retrieve/pii/S0733521011000774
# 10.1016/j.carres.2015.03.016 http://linkinghub.elsevier.com/retrieve/pii/S0008621515001007
# 10.1088/0004-637x/704/1/341 http://iopscience.iop.org/article/10.1088/0004-637X/704/1/341/meta;jsessionid=B6ECAD0419420F5DD5185DFC2A27D8C0.c4.iopscience.cld.iop.org
# 10.4085/1062-6050-50.1.13 http://natajournals.org/doi/10.4085/1062-6050-50.1.13?code=nata-site
# 10.1097/brs.0b013e3181e574f5 timeout
# 10.1186/1471-2474-14-19 https://bmcmusculoskeletdisord.biomedcentral.com/articles/10.1186/1471-2474-14-19
# 10.1002/prot.22988 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/prot.22988
# 10.1021/nn1020067 http://pubs.acs.org/doi/abs/10.1021/nn1020067
# 10.1104/pp.109.151712 http://www.plantphysiol.org/content/152/3/1209
# 10.1051/0004-6361/201321293 https://www.aanda.org/articles/aa/abs/2013/08/aa21293-13/aa21293-13.html
# 10.1016/j.vph.2013.03.001 http://linkinghub.elsevier.com/retrieve/pii/S1537189113000281
# 10.1016/j.physleta.2011.06.012 http://linkinghub.elsevier.com/retrieve/pii/S0375960111007213
# 10.1080/02664760802443962 http://www.tandfonline.com/doi/full/10.1080/02664760802443962
# 10.3109/08037051.2012.759331 http://www.tandfonline.com/doi/full/10.3109/08037051.2012.759331
# 10.2166/wst.2014.508 http://wst.iwaponline.com/content/71/2/277
# 10.1148/rg.302095124 http://pubs.rsna.org/doi/10.1148/rg.302095124
# 10.2306/scienceasia1513-1874.2011.37.051 http://www.scienceasia.org/content/viewabstract.php?ms=2774
# 10.1007/s00431-010-1271-y https://link.springer.com/article/10.1007%2Fs00431-010-1271-y
# 10.1140/epjst/e2012-01677-0 https://link.springer.com/article/10.1140%2Fepjst%2Fe2012-01677-0
# 10.1007/s11095-010-0118-6 https://link.springer.com/article/10.1007%2Fs11095-010-0118-6
# 10.1140/epjp/i2014-14175-2 https://link.springer.com/article/10.1140%2Fepjp%2Fi2014-14175-2
# 10.1111/j.1447-0756.2010.01324.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1447-0756.2010.01324.x
# 10.1166/mex.2014.1150 http://www.ingentaconnect.com/content/asp/me/2014/00000004/00000002/art00006
# 10.1016/j.topol.2011.10.018 http://linkinghub.elsevier.com/retrieve/pii/S0166864111004883
# 10.1016/j.jviromet.2009.01.026 http://linkinghub.elsevier.com/retrieve/pii/S0166093409000196
# 10.1088/0022-3727/47/14/145204 timeout
# 10.1039/c4ra14617d ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s00382-014-2206-5 https://link.springer.com/article/10.1007%2Fs00382-014-2206-5
# 10.1007/s12975-012-0187-4 https://link.springer.com/article/10.1007%2Fs12975-012-0187-4
# 10.5897/ajmr11.1594 http://academicjournals.org/login
# 10.1063/1.3477962 http://aip.scitation.org/doi/10.1063/1.3477962
# 10.1016/j.synthmet.2008.11.016 http://linkinghub.elsevier.com/retrieve/pii/S0379677908003846
# 10.1016/j.indcrop.2015.07.046 http://linkinghub.elsevier.com/retrieve/pii/S0926669015302703
# 10.3389/fpsyg.2014.01090 https://www.frontiersin.org/articles/10.3389/fpsyg.2014.01090/full
# 10.3109/10641960902825461 http://www.tandfonline.com/doi/full/10.3109/10641960902825461
# 10.1109/tmag.2011.2172976 http://ieeexplore.ieee.org:80/document/6136489/?reload=true
# 10.1038/sj.bdj.2012.889 http://www.nature.com/bdj/journal/v213/n7/full/sj.bdj.2012.889.html
# 10.1177/0954008314531030 http://journals.sagepub.com/doi/10.1177/0954008314531030
# 10.1111/j.1365-2842.2011.02202.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1365-2842.2011.02202.x
# 10.1016/j.jmacro.2014.08.007 http://linkinghub.elsevier.com/retrieve/pii/S0164070414001062
# 10.1016/j.atherosclerosis.2010.11.013 http://linkinghub.elsevier.com/retrieve/pii/S0021915010009135
# 10.1016/j.neuron.2009.03.001 http://linkinghub.elsevier.com/retrieve/pii/S0896627309001986
# 10.1016/j.jviromet.2010.03.024 http://linkinghub.elsevier.com/retrieve/pii/S0166093410001126
# 10.1089/hum.2013.142 http://online.liebertpub.com/doi/abs/10.1089/hum.2013.142
# 10.1097/mib.0000000000000408 too_many_redirects
# 10.1007/jhep10(2012)158 https://link.springer.com/article/10.1007%2FJHEP10%282012%29158
# 10.1186/1756-3305-4-183 https://parasitesandvectors.biomedcentral.com/articles/10.1186/1756-3305-4-183
# 10.1007/s00396-010-2200-3 https://link.springer.com/article/10.1007%2Fs00396-010-2200-3
# 10.1007/s00120-009-2031-3 https://link.springer.com/article/10.1007%2Fs00120-009-2031-3
# 10.4049/jimmunol.0900295 http://www.jimmunol.org/content/183/2/1313
# 10.1111/j.1538-7836.2011.04494.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1538-7836.2011.04494.x
# 10.1002/asjc.211 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/asjc.211
# 10.1063/1.3490188 http://aip.scitation.org/doi/10.1063/1.3490188
# 10.1016/j.ijrmhm.2015.02.003 http://linkinghub.elsevier.com/retrieve/pii/S0263436815000220
# 10.1016/j.brainres.2010.03.026 http://linkinghub.elsevier.com/retrieve/pii/S0006899310005706
# 10.1080/08912960903295843 http://www.tandfonline.com/doi/abs/10.1080/08912960903295843
# 10.1080/14772019.2014.936974 http://www.tandfonline.com/doi/full/10.1080/14772019.2014.936974
# 10.1088/1367-2630/13/4/045017 http://iopscience.iop.org/article/10.1088/1367-2630/13/4/045017/meta;jsessionid=AD3F2A6DEF1ADEE11281A9BE916C7108.c1.iopscience.cld.iop.org
# 10.1089/ars.2013.5757 http://online.liebertpub.com/doi/abs/10.1089/ars.2013.5757
# 10.1038/bmt.2009.326 http://www.nature.com/bmt/journal/v45/n7/full/bmt2009326a.html
# 10.1258/ar.2011.110463 timeout
# 10.1111/obr.12166 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/obr.12166
# 10.1103/physrevb.79.235313 https://journals.aps.org/prb/abstract/10.1103/PhysRevB.79.235313
# 10.1128/aac.00771-15 http://aac.asm.org/content/59/9/5413
# 10.1016/j.geomphys.2012.07.008 http://linkinghub.elsevier.com/retrieve/pii/S0393044012001428
# 10.1016/j.toxicon.2012.07.016 http://linkinghub.elsevier.com/retrieve/pii/S0041010112005612
# 10.1016/j.jaridenv.2014.01.002 timeout
# 10.1088/0004-637x/693/1/847 timeout
# 10.1111/j.1364-3703.2009.00583.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1364-3703.2009.00583.x
# 10.1037/a0021529 http://doi.apa.org/doiLanding?doi=10.1037/a0021529
# 10.1016/j.soilbio.2013.08.014 http://linkinghub.elsevier.com/retrieve/pii/S0038071713002794
# 10.1016/j.mrfmmm.2014.04.001 http://linkinghub.elsevier.com/retrieve/pii/S0027510714000670
# 10.1016/j.atmosenv.2013.08.043 http://linkinghub.elsevier.com/retrieve/pii/S1352231013006638
# 10.1107/s1744309109001316 http://scripts.iucr.org/cgi-bin/paper?S1744309109001316
# 10.1093/rheumatology/keu254 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1371/journal.pone.0062113 http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0062113
# 10.1039/c5cc05902j ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s11868-015-0121-0 https://link.springer.com/article/10.1007%2Fs11868-015-0121-0
# 10.1166/jnn.2011.4440 http://www.ingentaconnect.com/content/asp/jnn/2011/00000011/00000007/art00161
# 10.1016/j.socscimed.2008.10.002 http://linkinghub.elsevier.com/retrieve/pii/S0277953608005236
# 10.1016/j.beproc.2013.02.016 http://linkinghub.elsevier.com/retrieve/pii/S0376635713000387
# 10.1088/0951-7715/28/8/2743 timeout
# 10.1089/rej.2010.1101 http://online.liebertpub.com/doi/abs/10.1089/rej.2010.1101
# 10.1016/j.asj.2009.02.007 ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# 10.1371/journal.pgen.1000437 http://journals.plos.org/plosgenetics/article?id=10.1371/journal.pgen.1000437
# 10.1039/b813498g ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1186/s40064-015-1173-6 https://springerplus.springeropen.com/articles/10.1186/s40064-015-1173-6
# 10.1186/1472-6920-14-46 https://bmcmededuc.biomedcentral.com/articles/10.1186/1472-6920-14-46
# 10.7868/s0044513412120033 https://www.crossref.org/iPage?doi=10.7868%2FS0044513412120033
# 10.1016/j.mce.2015.08.008 http://linkinghub.elsevier.com/retrieve/pii/S0303720715300484
# 10.1016/j.conengprac.2009.06.011 http://linkinghub.elsevier.com/retrieve/pii/S0967066109001324
# 10.1016/j.anndiagpath.2010.06.003 http://linkinghub.elsevier.com/retrieve/pii/S1092913410001024
# 10.1016/j.brainres.2011.07.020 http://linkinghub.elsevier.com/retrieve/pii/S0006899311012789
# 10.1109/tia.2013.2270971 http://ieeexplore.ieee.org:80/document/6553091/?reload=true
# 10.1039/b807345g ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.3892/or.2015.4079 https://www.spandidos-publications.com/
# 10.1186/1479-5876-9-30 https://translational-medicine.biomedcentral.com/articles/10.1186/1479-5876-9-30
# 10.1007/s00248-014-0514-2 https://link.springer.com/article/10.1007%2Fs00248-014-0514-2
# 10.1364/oe.23.022330 https://www.osapublishing.org/oe/abstract.cfm?uri=oe-23-17-22330
# 10.1515/jpem-2012-0293 https://www.degruyter.com/view/j/jpem.2013.26.issue-1-2/jpem-2012-0293/jpem-2012-0293.xml
# 10.1021/ef400865h http://pubs.acs.org/doi/abs/10.1021/ef400865h
# 10.1021/jp2006827 http://pubs.acs.org/doi/abs/10.1021/jp2006827
# 10.1016/j.biocon.2015.08.012 http://linkinghub.elsevier.com/retrieve/pii/S0006320715300628
# 10.1016/j.rgg.2009.12.014 http://linkinghub.elsevier.com/retrieve/pii/S1068797109002697
# 10.1016/j.aquaculture.2011.08.023 http://linkinghub.elsevier.com/retrieve/pii/S0044848611006478
# 10.1089/aid.2009.0123 http://online.liebertpub.com/doi/abs/10.1089/aid.2009.0123
# 10.1039/c5ra15890g ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s00227-015-2694-9 https://link.springer.com/article/10.1007%2Fs00227-015-2694-9
# 10.1063/1.4891676 http://aip.scitation.org/doi/10.1063/1.4891676
# 10.1021/bi401034q http://pubs.acs.org/doi/abs/10.1021/bi401034q
# 10.1016/j.oraloncology.2008.12.008 http://linkinghub.elsevier.com/retrieve/pii/S1368837508003795
# 10.1016/j.corsci.2011.08.021 http://linkinghub.elsevier.com/retrieve/pii/S0010938X11004343
# 10.1016/j.ijrmhm.2015.03.008 http://linkinghub.elsevier.com/retrieve/pii/S026343681500058X
# 10.1016/j.cytogfr.2013.08.002 http://linkinghub.elsevier.com/retrieve/pii/S1359610113000774
# 10.1016/j.molmed.2011.03.005 http://linkinghub.elsevier.com/retrieve/pii/S1471491411000633
# 10.2217/fon.12.29 https://www.futuremedicine.com/doi/10.2217/fon.12.29
# 10.5012/bkcs.2011.32.9.3505 timeout
# 10.1364/oe.21.010667 https://www.osapublishing.org/oe/abstract.cfm?uri=oe-21-9-10667
# 10.1111/j.1471-4159.2009.06482.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1471-4159.2009.06482.x
# 10.1002/pssr.201409046 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/pssr.201409046
# 10.1902/jop.2009.080375 http://www.joponline.org/doi/10.1902/jop.2009.080375
# 10.1016/j.energy.2013.03.021 http://linkinghub.elsevier.com/retrieve/pii/S0360544213002090
# 10.1016/j.destud.2013.11.001 http://linkinghub.elsevier.com/retrieve/pii/S0142694X13000793
# 10.1080/10584587.2014.902719 http://www.tandfonline.com/doi/abs/10.1080/10584587.2014.902719
# 10.1099/vir.0.023507-0 http://jgv.microbiologyresearch.org/content/journal/jgv/10.1099/vir.0.023507-0
# 10.1039/c0cc03153d ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.1007/s00104-014-2789-8 https://link.springer.com/article/10.1007%2Fs00104-014-2789-8
# 10.1111/j.1440-1827.2009.02350.x http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1111/j.1440-1827.2009.02350.x
# 10.1128/aem.01460-10 http://aem.asm.org/content/77/8/2640
# 10.1182/blood-2012-08-452292 http://www.bloodjournal.org/content/121/21/e129?sso-checked=true
# 10.1016/j.optcom.2012.07.101 http://linkinghub.elsevier.com/retrieve/pii/S0030401812008231
# 10.1016/j.jcat.2009.04.012 http://linkinghub.elsevier.com/retrieve/pii/S0021951709001249
# 10.5935/1678-9741.20120048 timeout
# 10.1080/0907676x.2012.722654 http://www.tandfonline.com/doi/abs/10.1080/0907676X.2012.722654
# 10.3233/ifs-141447 http://www.medra.org/servlet/aliasResolver?alias=iospress&doi=10.3233/IFS-141447
# 10.7567/jjap.53.093003 timeout
# 10.1134/s0023158409060123 https://link.springer.com/article/10.1134%2FS0023158409060123
# 10.1007/s00259-015-3059-9 https://link.springer.com/article/10.1007%2Fs00259-015-3059-9
# 10.1002/ijc.27454 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/ijc.27454
# 10.1021/ed300017a http://pubs.acs.org/doi/abs/10.1021/ed300017a
# 10.1166/sam.2012.1401 http://www.ingentaconnect.com/content/asp/sam
# 10.1017/s0950268814003434 timeout
# 10.1016/j.ijhydene.2015.06.155 http://linkinghub.elsevier.com/retrieve/pii/S0360319915016845
# 10.1016/j.jsv.2011.08.029 http://linkinghub.elsevier.com/retrieve/pii/S0022460X11007140
# 10.1016/j.gca.2013.05.014 http://linkinghub.elsevier.com/retrieve/pii/S0016703713002871
# 10.1016/j.ijfoodmicro.2011.04.005 http://linkinghub.elsevier.com/retrieve/pii/S0168160511002054
# 10.1080/01630563.2011.618899 http://www.tandfonline.com/doi/abs/10.1080/01630563.2011.618899
# 10.1109/jlt.2009.2024172 http://ieeexplore.ieee.org:80/document/5061870/?reload=true
# 10.1039/c2ra20393f ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# 10.3928/1081597x-20150521-11 https://www.healio.com/doiresolver?doi=10.3928/1081597X-20150521-11
# 10.1007/s40266-015-0244-2 https://link.springer.com/article/10.1007%2Fs40266-015-0244-2
# 10.1002/pc.21050 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/pc.21050
# 10.1375/twin.14.2.111 timeout
# 10.1016/j.jim.2009.07.003 http://linkinghub.elsevier.com/retrieve/pii/S0022175909002002
# 10.1002/pssb.200983085 http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/pssb.200983085
# 10.1063/1.4733344 http://aip.scitation.org/doi/10.1063/1.4733344
# 10.1016/j.ijintrel.2013.08.009 http://linkinghub.elsevier.com/retrieve/pii/S0147176713000916
# 10.1016/j.techfore.2011.01.010 http://linkinghub.elsevier.com/retrieve/pii/S0040162511000138
# 10.1016/j.tourman.2011.06.011 http://linkinghub.elsevier.com/retrieve/pii/S0261517711001221
# 10.1080/01431161.2011.576709 http://www.tandfonline.com/doi/abs/10.1080/01431161.2011.576709
# 10.1159/000342080 https://www.karger.com/Article/Abstract/342080
# 10.1186/1471-2172-14-16 https://bmcimmunol.biomedcentral.com/articles/10.1186/1471-2172-14-16
# 10.1007/s10695-012-9701-6 https://link.springer.com/article/10.1007%2Fs10695-012-9701-6
# 10.1007/s10620-012-2412-0 https://link.springer.com/article/10.1007%2Fs10620-012-2412-0
# 10.1037/a0019245 http://doi.apa.org/doiLanding?doi=10.1037/a0019245
# 10.1016/j.automatica.2014.05.022 http://linkinghub.elsevier.com/retrieve/pii/S000510981400212X

# %% [markdown]
# # Problems
#
# Problems that I encountered are documented here

# %% [markdown]
# ## 1. Facebook API returning less shares than Altmetric.com
#
# Example DOI: [10.1186/1741-7007-10-51](10.1186/1741-7007-10-51) which resolves to this URL https://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51
#
# Detailed Altmetric results for the DOI: [Altmetric results](https://biomedcentral.altmetric.com/details/799209/facebook)
#
# http://www.biomedcentral.com/1741-7007/10/51/

# %%
url = "http://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51"
doi = "10.1186/1741-7007-10-51"

# %% [markdown]
# ### Results per Altmetric API

# %%
alt_url = altmetric.uri(url, fetch=True)
alt_doi = altmetric.doi(doi, fetch=True)

print("DOI and ULR have same altmetric_id: {}".format(alt_url['altmetric_id'] == alt_doi['altmetric_id']))

print("FB shares: {}".format(alt_doi['counts']['facebook']['posts_count']))
# Out:
# DOI and ULR have same altmetric_id: True
# FB shares: 38

# %% [markdown]
# ### Results per Facebook API

# %%
fb_url = fb_graph.get_object(url, fields="engagement, og_object")
fb_doi = fb_graph.get_object("http://dx.doi.org/" + doi, fields="engagement, og_object")

print("DOI and ULR have same og_object_id: {}".format(fb_url['og_object']['id'] == fb_doi['og_object']['id']))

print("FB shares for URL: {}".format(fb_url['engagement']['share_count']))
print("FB shares for DOI: {}".format(fb_doi['engagement']['share_count']))
# Out:
# DOI and ULR have same og_object_id: False
# FB shares for URL: 1
# FB shares for DOI: 0

# %% [markdown]
# ## 2. URL <-> OpenGraph object ID
#
# Not cool behaviour...

# %%
url_base = "bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51"
doi = "10.1186/1741-7007-10-51"

url_base = "www.nature.com/news/the-future-of-dna-sequencing-1.22787"
doi = "10.1038/550179a"

urls = ['http://' + url_base,
        'http://' + url_base + '/',
        'https://' + url_base,
        'https://' + url_base + '/']

dois = ['http://dx.doi.org/' + doi,
        'https://dx.doi.org/' + doi,
        'http://doi.org/' + doi,
        'https://doi.org/' + doi]

url_results = {}
doi_results = {}

for url in urls:
    try:
        url_results[url] = fb_graph.get_object(url, fields="og_object")['og_object']['id']
    except:
        url_results[url] = None
        
for doi in dois:
    try:
        doi_results[doi] = fb_graph.get_object(doi, fields="og_object")['og_object']['id']
    except:
        doi_results[doi] = None
        
pprint(url_results)
pprint(doi_results)
# Out:
# {'http://www.nature.com/news/the-future-of-dna-sequencing-1.22787': '1472429859490322',
#  'http://www.nature.com/news/the-future-of-dna-sequencing-1.22787/': '1446759318778508',
#  'https://www.nature.com/news/the-future-of-dna-sequencing-1.22787': '1472429859490322',
#  'https://www.nature.com/news/the-future-of-dna-sequencing-1.22787/': '1649534128454620'}
# {'http://doi.org/10.1038/550179a': None,
#  'http://dx.doi.org/10.1038/550179a': '1472429859490322',
#  'https://doi.org/10.1038/550179a': None,
#  'https://dx.doi.org/10.1038/550179a': None}

# %%
url_base = "bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51"
doi = "10.1186/1741-7007-10-51"

urls = ['http://' + url_base,
        'http://' + url_base + '/',
        'https://' + url_base,
        'https://' + url_base + '/']

dois = ['http://dx.doi.org/' + doi,
        'https://dx.doi.org/' + doi,
        'http://doi.org/' + doi,
        'https://doi.org/' + doi]

url_results = {}
doi_results = {}

for url in urls:
    try:
        url_results[url] = fb_graph.get_object(url, fields="og_object")['og_object']['id']
    except:
        url_results[url] = None
        
for doi in dois:
    try:
        doi_results[doi] = fb_graph.get_object(doi, fields="og_object")['og_object']['id']
    except:
        doi_results[doi] = None
        
pprint(url_results)
pprint(doi_results)
# Out:
# {'http://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51': '1246877015357759',
#  'http://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51/': '2058851297473624',
#  'https://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51': '2058851297473624',
#  'https://bmcbiol.biomedcentral.com/articles/10.1186/1741-7007-10-51/': '2058851297473624'}
# {'http://doi.org/10.1186/1741-7007-10-51': '2058851297473624',
#  'http://dx.doi.org/10.1186/1741-7007-10-51': '2058851297473624',
#  'https://doi.org/10.1186/1741-7007-10-51': '2058851297473624',
#  'https://dx.doi.org/10.1186/1741-7007-10-51': '2058851297473624'}
